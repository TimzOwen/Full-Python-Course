# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib 

# step 1
#load the model that has been trained
model = joblib.load('music_recommender.joblib')  # remove the model defined as its already trained
model_prediction = model.predict([[25,0]])  # test with a sample prediction
model_prediction          # print the prediction
# Out:
# array(['jaz'], dtype=object)

# %%
# print music data to crosscheck its accuracy
music_data
# Out:
#     age  gender       genre
# 0    18        1      Hipop
# 1    19        1      Hipop
# 2    20        1      Hipop
# 3    25        0        jaz
# 4    26        0        jaz
# 5    27        0        jaz
# 6    30        1  classical
# 7    31        1  classical
# 8    31        1  classical
# 9    35        0      Bongo
# 10   26        0      Bongo
# 11   37        0      Bongo
# 12   40        1     rhumba
# 13   41        1     rhumba
# 14   42        1     rhumba
# 15   50        0      regee
# 16   51        0      regee
# 17   52        0      regee
# 18   60        1     gospel
# 19   61        1     gospel
# 20   62        1     gospel
